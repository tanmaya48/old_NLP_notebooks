# %%
import pandas as pd

train_data = pd.read_csv('data.csv')
##train_data.pop('Unnamed: 0')
train_data.dropna(inplace = True)

# %%
train_data.tail(20)
# Out:
#      Unnamed: 0      Name                                              About  \
# 133         133  broccoli  Broccoli is an edible green plant in the cabba...
# 134         134      bean  A bean is the seed of one of several genera of...
# 135         135    quinoa  Quinoa (Chenopodium quinoa; /ˈkiːnwɑː/ or /kɪˈ...
# 136         136    carrot  The carrot (Daucus carota subsp. sativus) is a...
# 137         137    peanut  The peanut, also known as the groundnut,[2] go...
# 138         138  beetroot  Besides being used as a food, beets have uses ...
# 139         139   lettuce  Lettuce (Lactuca sativa) is an annual plant of...
# 140         140       pea  The pea is most commonly the small spherical s...
# 141         141  eggplant   Solanum ovigerum Dunal\nSolanum trongum Poir....
# 142         142  cucumber  Cucumber (Cucumis sativus) is a widely-cultiva...
# 143         143   spinach  Spinach (Spinacia oleracea) is a leafy green f...
# 144         144   raddish  The radish (Raphanus raphanistrum subsp. sativ...
# 145         145    butter  Butter is a dairy product made from the fat an...
# 146         146     grape  A grape is a fruit, botanically a berry, of th...
# 147         147      wine  Wine has been produced for thousands of years....
# 148         148   coconut  The coconut tree (Cocos nucifera) is a member ...
# 149         149     lemon   The lemon, Citrus limon, is a species of smal...
# 150         150  lemonade  Lemonade is a sweetened lemon-flavored beverag...
# 151         151       tea   Tea is an aromatic beverage commonly prepared...
# 152         152    coffee  Coffee is a brewed drink prepared from roasted...
#
#     Category
# 133     food
# 134     food
# 135     food
# 136     food
# 137     food
# 138     food
# 139     food
# 140     food
# 141     food
# 142     food
# 143     food
# 144     food
# 145     food
# 146     food
# 147     food
# 148     food
# 149     food
# 150     food
# 151     food
# 152     food

# %%
import re
from nltk.corpus import stopwords
from bs4 import BeautifulSoup



#creating a function to clean the reviews
def formated( raw_review ):
    
    # 1. Remove HTML
    review_text = BeautifulSoup(raw_review).get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", review_text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    

    return( " ".join( meaningful_words ))

# %%
formated(train_data['About'][9])
# Out:
# 'list anuran families toad common name certain frogs especially family bufonidae characterized dry leathery skin short legs large bumps covering parotoid glands distinction frogs toads made scientific taxonomy common popular culture folk taxonomy toads associated drier rougher skin terrestrial habitats scientific taxonomy toads found families bufonidae bombinatoridae calyptocephalellidae discoglossidae myobatrachidae pelobatidae rhinophrynidae scaphiopodidae microhylidae'

# %%
train_data.shape
# Out:
# (153, 4)

# %%
new_texts = []

for i in range(0,153):
    
    text = formated(train_data['About'][i])
    new_texts.append(text)

# %%
train_data['About'] = new_texts

# %%
train_data.head(20)
# Out:
#     Unnamed: 0      Name                                              About  \
# 0            0       cat  cat felis catus domestic species small carnivo...
# 1            1       dog  canis familiaris linnaeus aegyptius linnaeus a...
# 2            2     tiger  tiger panthera tigris largest extant cat speci...
# 3            3      wolf  see subspecies canis lupus wolf canis lupus al...
# 4            4     shark  carcharhiniformes heterodontiformes hexanchifo...
# 5            5     whale  whales widely distributed diverse group fully ...
# 6            6      lion  lion panthera leo species family felidae membe...
# 7            7    shrimp  shrimp decapod crustaceans elongated bodies pr...
# 8            8      frog  archaeobatrachia mesobatrachia neobatrachia li...
# 9            9      toad  list anuran families toad common name certain ...
# 10          10    rabbit  rabbits small mammals family leporidae order l...
# 11          11      deer  deer hoofed ruminant mammals forming family ce...
# 12          12      bear  amphicynodontinae hemicyoninae ursavinae agrio...
# 13          13  elephant  elephants mammals family elephantidae largest ...
# 14          14    walrus  rosmarus rosmarus rosmarus divergens rosmarus ...
# 15          15    parrot  cacatuoidea cockatoos psittacoidea true parrot...
# 16          16  corvidae  corvidae cosmopolitan family oscine passerine ...
# 17          17      crab  crabs decapod crustaceans infraorder brachyura...
# 18          18     raven  raven one several larger bodied species genus ...
# 19          19     eagle  eagle common name many large birds prey famili...
#
#    Category
# 0    animal
# 1    animal
# 2    animal
# 3    animal
# 4    animal
# 5    animal
# 6    animal
# 7    animal
# 8    animal
# 9    animal
# 10   animal
# 11   animal
# 12   animal
# 13   animal
# 14   animal
# 15   animal
# 16   animal
# 17   animal
# 18   animal
# 19   animal

# %%
train_data = train_data.sample(frac=1).reset_index(drop=True)

# %%
train_data.head(10)
# Out:
#    Unnamed: 0     Name                                              About  \
# 0          82   russia  coordinates n e russia c russian federation tr...
# 1         148  coconut  coconut tree cocos nucifera member palm tree f...
# 2         122     rice  rice seed grass species oryza glaberrima afric...
# 3          72    india  india hindi bh rat officially republic india h...
# 4          60     pink  various shades pink color pink takes name flow...
# 5          58    green  green color blue yellow visible spectrum evoke...
# 6          32    snail  snail loose terms shelled gastropod name often...
# 7         139  lettuce  lettuce lactuca sativa annual plant daisy fami...
# 8         130   garlic  garlic allium sativum species onion genus alli...
# 9         124    wheat  references serial itis wheat grass widely cult...
#
#   Category
# 0  country
# 1     food
# 2     food
# 3  country
# 4    color
# 5    color
# 6   animal
# 7     food
# 8     food
# 9     food

# %%
def review_to_wordlist( review ):
    
    words = review.split()
    
    new_w = []
    for w in words:
        if len(w) > 2:
            if len(w) < 20:
                new_w.append(w)
            
    return new_w

# %%
# Download the punkt tokenizer for sentence splitting
import nltk.data
import nltk
nltk.download('punkt')

from nltk import word_tokenize,sent_tokenize

# Load the punkt tokenizer
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# Define a function to split a review into parsed sentences
def review_to_sentences(review, tokenizer):
    # Function to split a review into parsed sentences. Returns a list of sentences, where each sentence is a list of words
    
    # 1. Use the NLTK tokenizer to split the paragraph into sentences
    raw_sentences = tokenizer.tokenize(review.strip())
    
    # 2. Loop over each sentence
    sentences = []
    for raw_sentence in raw_sentences:
        # If a sentence is empty, skip it
        if len(raw_sentence) > 0:
            # Otherwise, call review_to_wordlist to get a list of words
            sentences.append( review_to_wordlist( raw_sentence))
    #
    # Return the list of sentences (each sentence is a list of words,
    # so this returns a list of lists
    return sentences
# Out:
# [nltk_data] Downloading package punkt to /home/ce/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
sentences = []  # Initialize an empty list of sentences

print("Parsing sentences from training set")
for review in train_data["About"]:
    sentences += review_to_sentences(review, tokenizer)
# Out:
# Parsing sentences from training set

# %%
# Set values for various parameters
num_features = 100    # Word vector dimensionality                      
min_word_count = 20  # Minimum word count                        
num_workers = 4       # Number of threads to run in parallel
context = 10         # Context window size                                                                                    
downsampling = 1e-3   # Downsample setting for frequent words

# Initialize and train the model (this will take some time)
from gensim.models import word2vec
print("Training model...")
model = word2vec.Word2Vec(sentences, workers=num_workers, \
            size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling)

# If you don't plan to train the model any further, calling 
# init_sims will make the model much more memory-efficient.
model.init_sims(replace=True)

# It can be helpful to create a meaningful model name and 
# save the model for later use. You can load it later using Word2Vec.load()
model_name = "model_1_300f_40mw_10c"
model.save(model_name)
# Out:
# Training model...

# %%
model.wv.vocab
# Out:
# {'coordinates': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf667c0>,
#  'russia': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf66fa0>,
#  'russian': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf664c0>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf66a60>,
#  'located': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf66490>,
#  'eastern': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf669d0>,
#  'europe': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf66430>,
#  'northern': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf668e0>,
#  'asia': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf66dc0>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf666a0>,
#  'square': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf666d0>,
#  'kilometres': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf66fd0>,
#  'largest': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf66a00>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf66f70>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf66070>,
#  'inhabited': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf66af0>,
#  'land': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf66970>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf66820>,
#  'nations': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf66f10>,
#  'territory': <gensim.models.keyedvectors.Vocab at 0x7f2d7cf66be0>,
#  'baltic': <gensim.models.keyedvectors.Vocab at 0x7f2d811d2d00>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x7f2d811d2af0>,
#  'west': <gensim.models.keyedvectors.Vocab at 0x7f2d811d29a0>,
#  'pacific': <gensim.models.keyedvectors.Vocab at 0x7f2d811d22e0>,
#  'ocean': <gensim.models.keyedvectors.Vocab at 0x7f2d811d2eb0>,
#  'east': <gensim.models.keyedvectors.Vocab at 0x7f2d811d28b0>,
#  'north': <gensim.models.keyedvectors.Vocab at 0x7f2d811d2a30>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7f2d811d25e0>,
#  'south': <gensim.models.keyedvectors.Vocab at 0x7f2d811d2d60>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x7f2d811d2820>,
#  'living': <gensim.models.keyedvectors.Vocab at 0x7f2d811d2340>,
#  'federal': <gensim.models.keyedvectors.Vocab at 0x7f2d811d2a00>,
#  'populous': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd412b0>,
#  'nation': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41070>,
#  'capital': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd410d0>,
#  'city': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41130>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41190>,
#  'areas': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd411f0>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41250>,
#  'emerged': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd412e0>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41340>,
#  'centuries': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd413a0>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41400>,
#  'century': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41460>,
#  'empire': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd414c0>,
#  'culture': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41520>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41580>,
#  'states': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41610>,
#  'became': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41640>,
#  'european': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd416a0>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41700>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41760>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd417c0>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41820>,
#  'revolution': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41880>,
#  'soviet': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd418e0>,
#  'union': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41940>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd419a0>,
#  'war': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41a00>,
#  'united': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41a60>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41ac0>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41b20>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41b80>,
#  'humans': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41be0>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41c40>,
#  'republic': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41ca0>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41d00>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41d60>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41dc0>,
#  'government': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41e20>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41e80>,
#  'economy': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41ee0>,
#  'gdp': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41f40>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd41fa0>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37040>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd370a0>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37100>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37160>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd371c0>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37220>,
#  'economic': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37280>,
#  'organization': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd372e0>,
#  'international': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37340>,
#  'trade': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd373a0>,
#  'independent': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37400>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37460>,
#  'species': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd374c0>,
#  'genus': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37520>,
#  'term': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37580>,
#  'fruit': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd375e0>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37640>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd376a0>,
#  'portuguese': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37700>,
#  'spanish': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37760>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd377c0>,
#  'meaning': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37820>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37880>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd378e0>,
#  'tropical': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37940>,
#  'regions': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd379a0>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37a00>,
#  'referred': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37a60>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37ac0>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37b20>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37b80>,
#  'milk': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37be0>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37c40>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37ca0>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37d00>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37d60>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37dc0>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37e20>,
#  'seeds': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37e80>,
#  'plant': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37ee0>,
#  'derived': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37f40>,
#  'commonly': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd37fa0>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b040>,
#  'leaves': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b0a0>,
#  'variety': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b100>,
#  'india': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b160>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b1c0>,
#  'led': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b220>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b280>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b2e0>,
#  'spread': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b340>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b3a0>,
#  'america': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b400>,
#  'islands': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b460>,
#  'per': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b4c0>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b520>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b5b0>,
#  'plants': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b610>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b670>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b6d0>,
#  'indian': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b730>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b790>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b7f0>,
#  'african': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b850>,
#  'widely': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b8b0>,
#  'population': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b910>,
#  'africa': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b9a0>,
#  'highest': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b9d0>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3ba30>,
#  'varieties': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3ba90>,
#  'grown': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3baf0>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3bb50>,
#  'crop': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3bbb0>,
#  'countries': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3bc10>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3bc70>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3b640>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3bd60>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3bdc0>,
#  'native': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3be20>,
#  'parts': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3be80>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3bee0>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3bf40>,
#  'officially': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3bfa0>,
#  'southwest': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3bd30>,
#  'southeast': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e040>,
#  'borders': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e0a0>,
#  'china': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e100>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e160>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e1c0>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e220>,
#  'highly': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e280>,
#  'western': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e2e0>,
#  'bce': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e370>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e3d0>,
#  'language': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e430>,
#  'languages': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e490>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e4f0>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e550>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e5b0>,
#  'southern': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e610>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e670>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e6d0>,
#  'rule': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e730>,
#  'british': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e790>,
#  'began': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e7f0>,
#  'root': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e850>,
#  'democratic': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e8b0>,
#  'ethnic': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e910>,
#  'includes': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e940>,
#  'military': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3e9a0>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3ea00>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3ea60>,
#  'members': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3eac0>,
#  'japan': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3eb20>,
#  'associated': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3eb80>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3ec10>,
#  'blue': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3ec70>,
#  'yellow': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3ecd0>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3ed30>,
#  'colors': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3ed90>,
#  'along': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3edf0>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3ee50>,
#  'sometimes': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3eeb0>,
#  'groups': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3eee0>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3ef40>,
#  'english': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd3efa0>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31040>,
#  'german': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd310a0>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31100>,
#  'numerous': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31160>,
#  'mostly': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31220>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31280>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd312e0>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31340>,
#  'vegetable': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd313a0>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31400>,
#  'throughout': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31460>,
#  'ancient': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd314c0>,
#  'development': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd314f0>,
#  'generally': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31550>,
#  'cultivated': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd315b0>,
#  'source': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31610>,
#  'linnaeus': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31670>,
#  'wild': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd316d0>,
#  'domesticated': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31730>,
#  'garlic': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd317c0>,
#  'allium': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd311f0>,
#  'onion': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31850>,
#  'chinese': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd318b0>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31910>,
#  'approximately': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31970>,
#  'purple': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd319d0>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31a30>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31a60>,
#  'greek': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31af0>,
#  'french': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31b50>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31bb0>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31c10>,
#  'typically': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31c70>,
#  'usually': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31cd0>,
#  'colour': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31d60>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31ac0>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31df0>,
#  'latin': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31e50>,
#  'kingdom': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31eb0>,
#  'considered': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31f10>,
#  'according': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31f70>,
#  'animals': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd31fd0>,
#  'genera': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30040>,
#  'grey': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd300d0>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30130>,
#  'birds': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd301c0>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30220>,
#  'fish': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30280>,
#  'squid': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd302e0>,
#  'extant': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30370>,
#  'larger': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd300a0>,
#  'adult': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30400>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30460>,
#  'listen': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd304c0>,
#  'dynasty': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30520>,
#  'male': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30580>,
#  'independence': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd305e0>,
#  'populations': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd306a0>,
#  'developed': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30700>,
#  'established': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30760>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30790>,
#  'length': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd307f0>,
#  'gmelin': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30850>,
#  'wolf': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd308b0>,
#  'extinct': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30910>,
#  'domestic': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30940>,
#  'classified': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30970>,
#  'males': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd309d0>,
#  'females': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30a60>,
#  'prey': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30ac0>,
#  'mammals': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30b20>,
#  'france': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30b80>,
#  'coffee': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30be0>,
#  'primarily': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30340>,
#  'brazil': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30d00>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30d30>,
#  'mediterranean': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30d90>,
#  'period': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30df0>,
#  'roman': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30e50>,
#  'ottoman': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30eb0>,
#  'australia': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30ee0>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30f40>,
#  'indigenous': <gensim.models.keyedvectors.Vocab at 0x7f2d811d2fd0>,
#  'bordered': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30cd0>,
#  'finland': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd30fd0>,
#  'official': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f040>,
#  'national': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f0a0>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f100>,
#  'germany': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f160>,
#  'skin': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f1c0>,
#  'italian': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f220>,
#  'ukraine': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f280>,
#  'egypt': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f2e0>,
#  'eagles': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f340>,
#  'mexico': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f3a0>,
#  'kenya': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f400>,
#  'sudan': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f460>,
#  'italy': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f4c0>,
#  'atlantic': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f520>,
#  'wine': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f580>,
#  'cat': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f5e0>,
#  'whales': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f640>,
#  'dolphins': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f6a0>,
#  'arabic': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f700>,
#  'arab': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f760>,
#  'libya': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f7c0>,
#  'hyenas': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f820>,
#  'trout': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f880>,
#  'iraq': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f8e0>,
#  'butter': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f940>,
#  'dodo': <gensim.models.keyedvectors.Vocab at 0x7f2d7cd2f9a0>}

# %%
len(model.wv.vocab)
# Out:
# 311

# %%
model.wv.doesnt_match("brazil uruguay india green".split())
# Out:
# 'green'

# %%
vocab = model.wv.vocab
names = train_data['Name']

# %%
i = 0
for name in names:
    if name in vocab:
        i+=1
        
print(i)
# Out:
# 35

# %%
def makeFeatureVec(words, model, num_features):
    # Function to average all of the word vectors in a given paragraph
    
    # Pre-initialize an empty numpy array (for speed)
    featureVec = np.zeros((num_features,),dtype="float32")
    
    nwords = 0.
     
    # Index2word is a list that contains the names of the words in 
    # the model's vocabulary. Convert it to a set, for speed 
    index2word_set = set(model.wv.index2word)
    #
    # Loop over each word in the review and, if it is in the model's
    # vocaublary, add its feature vector to the total
    for word in words:
        if word in index2word_set: 
            nwords = nwords + 1.
            #here we are adding the feature vectors of all the words that were in the review
            featureVec = np.add(featureVec,model[word])
    # 
    # Divide the result by the number of words to get the average
    featureVec = np.divide(featureVec,nwords)
    return featureVec


def getAvgFeatureVecs(reviews, model, num_features):
    # Given a set of reviews (each one a list of words), calculate 
    # the average feature vector for each one and return a 2D numpy array 
    # 
    # Initialize a counter
    counter = 0
    # 
    # Preallocate a 2D numpy array, for speed
    reviewFeatureVecs = np.zeros((len(reviews),num_features),dtype="float32")
    # 
    # Loop through the reviews
    for review in reviews:
        # Print a status message every 1000th review
        if counter%1000 == 0:
            print("Review %d of %d" % (counter, len(reviews)))
        # Call the function (defined above) that makes average feature vectors
        reviewFeatureVecs[counter] = makeFeatureVec(review, model,num_features)
        # Increment the counter
        counter = counter + 1
    return reviewFeatureVecs

# %%
import numpy as np

clean_train_reviews = []
for review in train_data["About"]:
    clean_train_reviews.append( review_to_wordlist( review))

trainDataVecs = getAvgFeatureVecs( clean_train_reviews, model, num_features )
# Out:
# Review 0 of 153
# <ipython-input-77-e87961c1ce5f>:19: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   featureVec = np.add(featureVec,model[word])

# %%
from scipy import spatial

cosine_similarity = lambda vec1,vec2: 1 - spatial.distance.cosine(vec1,vec2)

def get_most_similar(n=0):
    
    similarities = []

    vec = trainDataVecs[n] 

    for i in range (0,len(trainDataVecs)):
    
        vec2 = trainDataVecs[i]
        similarities.append(cosine_similarity(vec,vec2))
          
        
    maxim = 0
    pos = 0
    for i in range(0,len(trainDataVecs)):
        
        if i == n:
            continue
            
        if(similarities[i]>maxim):
            maxim = similarities[i]
            pos = i
        
      
    return pos        
'''            
    print(train_data.iloc[n].review)
    print('##############################################################################')
    print()
    print('##############################################################################')
    print(train_data.iloc[pos].review)
    print(pos)
    print(maxim)
'''
# Out:
# "            \n    print(train_data.iloc[n].review)\n    print('##############################################################################')\n    print()\n    print('##############################################################################')\n    print(train_data.iloc[pos].review)\n    print(pos)\n    print(maxim)\n"

# %%
case = 11

print(names[case])

print(names[get_most_similar(case)])
# Out:
# cerulean
# russia
# coconut
# rice
# india
# pink
# green
# snail
# lettuce
# garlic
# wheat
# turquoise
# antelope
# penguin
# mongolia
# horse
# onion
# dog
# cucumber
# wolf
# vietnam
# coffee
# deer
# greece
# koala
# estonia
# corvidae
# belgium
# bangladesh
# yellow
# turtle
# magenta
# lithuania
# ostrich
# lemonade
# blue
# indonesia
# vulture
# eagle
# raven
# mexico
# lemur
# ethiopia
# france
# banana
# tiger
# goat
# germany
# latvia
# whale
# argentina
# ireland
# wildebeest
# armenia
# octopus
# qatar
# morocco
# canada
# viridian
# jaguar
# fox
# carrot
# pig
# parrot
# ukraine
# bear
# algeria
# milk
# elephant
# libya
# myanmar
# eggplant
# salmon
# swordfish
# norway
# bolivia
# quinoa
# portugal
# rabbit
# pea
# luxembourg
# red
# crocodile
# egypt
# toad
# china
# chicken
# iraq
# syria
# finland
# trout
# alligator
# tortoise
# shallot
# tea
# sudan
# teal
# squid
# bean
# hyena
# monkey
# sweden
# peanut
# crab
# lion
# hornbill
# cow
# butter
# camel
# purple
# australia
# beetroot
# shark
# italy
# lemon
# moldova
# kangaroo
# zebra
# dolphin
# lynx
# uzbekistan
# israel
# maize
# potato
# black
# cyan
# japan
# afganistan
# scallion
# walrus
# mouse
# grape
# tomato
# frog
# malaysia
# broccoli
# spinach
# brazil
# belarus
# wine
# spain
# uruguay
# cat
# vermilion
# shrimp
# panda
# pinniped
# white
# kenya
# dodo
# raddish
# poland
# hippo
# blue
